# %% [markdown]
# <a href="https://colab.research.google.com/github/shah9409/ObjectDetection/blob/main/TrainYolov8CustomDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od
import pandas
import locale

# %%
od.download("https://www.kaggle.com/datasets/nadinpethiyagoda/vehicle-dataset-for-yolo")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: vshah211
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 375M/375M [00:04<00:00, 88.3MB/s]

# %%
ROOT_DIR = '/content/vehicle-dataset-for-yolo'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.7/644.7 kB 6.8 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

#print(os.path.join(ROOT_DIR, "google_colab_config.yaml"))
# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "google_colab_config.yaml"), epochs=10)  # train the model
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# !zip -r /content/vehicle-dataset-for-yolo.zip /content/vehicle-dataset-for-yolo/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/van57.txt (deflated 8%)
#   adding: content/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/4AS6VDRS3Y07.txt (deflated 13%)
#   adding: content/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/threewheel8 (2).txt (deflated 11%)
#   adding: content/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/car294.txt (deflated 5%)
#   adding: content/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/0RW4I2NTAH8K.txt (deflated 11%)
#   adding: content/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/srilankatruck29.txt (deflated 8%)
#   adding: content/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/threewheel35.txt (deflated 30%)
#   adding: content/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/lorry156.txt (deflated 13%)
# ...

# %%
locale.getpreferredencoding = lambda: "UTF-8"
# !ls
# Out:
# runs  sample_data  vehicle-dataset-for-yolo  yolov8n.pt
